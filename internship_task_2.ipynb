# %% [markdown]
# <a href="https://colab.research.google.com/github/Gnanasree12/iiit_internship/blob/main/internship_task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import files

# Create a new folder in Colab
upload_folder = "images_folder"
os.makedirs(upload_folder, exist_ok=True)

# Upload images from your local folder (select all images from D:\f6\images_folder)
print("📤 Upload images from your 'D:\\f6\\images_folder'")
uploaded = files.upload()

# Move uploaded files into the created folder
for name in uploaded.keys():
    os.rename(name, f"{upload_folder}/{name}")

print("✅ Uploaded all images to 'images_folder/' in Colab.")
# Out:
# 📤 Upload images from your 'D:\f6\images_folder'
#      <input type="file" id="files-3033cbc8-4f80-438a-8f11-3e7737f47eda" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3033cbc8-4f80-438a-8f11-3e7737f47eda">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# Install Ultralytics
# !pip install ultralytics

# Import and use YOLO
from ultralytics import YOLO
model = YOLO("yolov8n-seg.pt")

# Segment uploaded images
results = model.predict(source="images_folder", save=True, name="segmented_images")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 17.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 100.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 74.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 75.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import shutil
shutil.make_archive("segmented_images", 'zip', "runs/segment/segmented_images")
files.download("segmented_images.zip")

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import os

model = YOLO("yolov8n-seg.pt")  # segmentation model

# Segment all images in the 'images_folder'
results = model.predict(source="images_folder", save=True, name="segmented_images")
# Out:
# image 1/1 /content/images_folder/street-city-car-buildings.jpg: 448x640 14 persons, 8 cars, 1 truck, 463.4ms
# Speed: 16.8ms preprocess, 463.4ms inference, 300.5ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/segment/segmented_images2

# %%
from google.colab import files
import os

# Upload a video from your local computer
print("📤 Upload a video file (MP4 preferred)")
uploaded_video = files.upload()

# Get video filename
video_filename = next(iter(uploaded_video))

# Create folder for extracted frames
os.makedirs("video_frames", exist_ok=True)

# Split video into frames using ffmpeg (every 1 frame per second)
# !ffmpeg -i "{video_filename}" -vf fps=1 video_frames/frame_%04d.jpg
# Out:
# 📤 Upload a video file (MP4 preferred)
#      <input type="file" id="files-db92928a-4037-4fe9-b503-43dde6609d9a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-db92928a-4037-4fe9-b503-43dde6609d9a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# Segment all frames
results = model.predict(source="video_frames", save=True, name="segmented_video_frames")
# Out:
# image 1/7 /content/video_frames/frame_0001.jpg: 480x640 12 persons, 5 cars, 2 buss, 1 truck, 261.9ms
# image 2/7 /content/video_frames/frame_0002.jpg: 480x640 10 persons, 1 bus, 228.1ms
# image 3/7 /content/video_frames/frame_0003.jpg: 480x640 5 persons, 5 cars, 2 trucks, 218.6ms
# image 4/7 /content/video_frames/frame_0004.jpg: 480x640 10 persons, 218.5ms
# image 5/7 /content/video_frames/frame_0005.jpg: 480x640 5 persons, 4 cars, 2 buss, 2 trucks, 1 traffic light, 217.7ms
# image 6/7 /content/video_frames/frame_0006.jpg: 480x640 11 persons, 2 cars, 1 bus, 1 traffic light, 220.0ms
# image 7/7 /content/video_frames/frame_0007.jpg: 480x640 16 persons, 2 cars, 1 bus, 214.5ms
# Speed: 4.4ms preprocess, 225.6ms inference, 53.2ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/segment/segmented_video_frames

# %%
# Create a video from segmented frames
# !ffmpeg -framerate 1 -i "runs/segment/segmented_video_frames/frame_%04d.jpg" -c:v libx264 -pix_fmt yuv420p output_segmented_video.mp4

# Download the final video
files.download("output_segmented_video.mp4")
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
